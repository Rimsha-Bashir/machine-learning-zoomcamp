# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
import tensorflow as tf 
from tensorflow import keras

# %%
tf.config.list_physical_devices('GPU') # to detect if you have a GPU
# Out:
# []

# %%
from tensorflow.keras.preprocessing.image import load_img

# %%
path = './clothing-dataset-small/train/t-shirt'
name = '5f0a3fa0-6a3d-4b68-b213-72766a643de7.jpg'
fullname = f'{path}/{name}'
load_img(fullname, target_size=(150,150))

# note that keras expects certain fixed size images, so we have to set it via the target_size parameter
# eg. (299,299) or (150,150) etc.
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
img = load_img(fullname, target_size=(150,150))
print(img)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x2DEACE94DD0>

# %% [markdown]
# ![image.png](attachment:5477e2d2-0a07-48be-9174-c557708956c1.png)
#
# **this is how the img is internally represented in the form of numpy arrays with r, g and b values.**

# %%
np.array(img)  # each row is a pixel with rgb value.
# Out:
# array([[[177, 169,  97],
#         [178, 169, 100],
#         [182, 173, 104],
#         ...,
#         [251, 253, 250],
#         [251, 253, 248],
#         [251, 254, 247]],
#
#        [[200, 190, 128],
#         [203, 193, 132],
#         [203, 193, 132],
#         ...,
#         [250, 251, 246],
#         [250, 251, 245],
#         [250, 251, 245]],
#
#        [[200, 189, 133],
#         [203, 192, 136],
#         [202, 191, 135],
#         ...,
#         [253, 250, 245],
#         [252, 249, 242],
#         [251, 248, 239]],
#
#        ...,
#
#        [[171, 157,  82],
#         [170, 156,  81],
#         [171, 157,  82],
#         ...,
#         [184, 142,  32],
#         [180, 133,  25],
#         [182, 135,  27]],
#
#        [[171, 157,  82],
#         [170, 156,  81],
#         [171, 157,  82],
#         ...,
#         [187, 144,  32],
#         [179, 132,  24],
#         [181, 134,  26]],
#
#        [[170, 156,  81],
#         [171, 157,  82],
#         [170, 156,  81],
# ...

# %%
x = np.array(img)
x.shape
# Out:
# (150, 150, 3)

# %% [markdown]
# ## Pre-trained convolution neural networks

# %% [markdown]
# https://keras.io/api/applications/ has models pre-trained on imagenet data (https://www.image-net.org/ - more than 1.2M images).
# so we can use this to classify our images.

# %% [markdown]
# let's take a look at Xception model. <Br>
# proceed to google colab!!
#
# https://colab.research.google.com/drive/1BQvZEn11J9XUZj8TqM2zA3gv22kyIahD?usp=sharing
